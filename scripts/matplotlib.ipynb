# %% [markdown]
# # Introduction à Matplotlib
#
# Dans ce TP, nous allons nous concentrer sur l'utilisation de [Matplotlib](https://matplotlib.org/) pour visualiser des données.
#
# Plutôt que de vous faire une liste des fonctions, nous allons travailler à partir d'exemples.
#
# Vous analyserez les résultats et complèterez les commentaires indiqués par des <span style="color:red">XXXXXXXX</span>.

# %%
# Mise en place l'environnement
# paramètre pour un affichage dans jupyter
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid') # style des graphiques
#plt.style.use('seaborn-v0_8-whitegrid')
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/matplotlib/style/core.py:129, in use(style)
#     128 try:
# --> 129     style = _rc_params_in_file(style)
#     130 except OSError as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/matplotlib/__init__.py:903, in _rc_params_in_file(fname, transform, fail_on_error)
#     902 rc_temp = {}
# --> 903 with _open_file_or_url(fname) as fd:
#     904     try:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#
# ...

# %% [markdown]
# ## 1. Tracer la courbe d'une fonction
#
# Commençons par tracer la courbe de la fonction sinus.
#
# La variable  fig  correspond à un conteneur qui contient tous les objets (axes, labels, données, etc). Les axes correspondent au carré que l'on voit au-dessus,  et qui contiendra par la suite les données du graphe.

# %%
fig = plt.figure()
ax = plt.axes()
fig = plt.figure()

# Renvoie des nombres régulièrement espacés sur un intervalle spécifié.
# Crée un tableau de 1000 valeurs, espacées uniformément entre 0 et 10
x = np.linspace(0, 10, 1000)
y = np.sin(x)

# Affiche la courbe de sinus
ax.plot(x, y);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       3 fig = plt.figure()
#       5 # Renvoie des nombres régulièrement espacés sur un intervalle spécifié.
#       6 # Crée un tableau de 1000 valeurs, espacées uniformément entre 0 et 10
# ----> 7 x = np.linspace(0, 10, 1000)
#       8 y = np.sin(x)
#      10 # Affiche la courbe de sinus
#
# NameError: name 'np' is not defined

# %%
# Changer la taille de police par défaut
plt.rcParams.update({'font.size': 15})

fig = plt.figure()
ax = plt.axes()

# Modifier l'affichage de la courbe : 
# Couleur spécifiée par son nom, type de ligne, valeur étiquette
plt.plot(x, np.sin(x - 0), color='blue', linestyle='solid', label='bleu')
# Nom court pour la couleur, ligne avec des traits
plt.plot(x, np.sin(x - 1), color='g', linestyle='dashed', label='vert', linewidth=10)
# Valeur de gris entre 0 et 1, des traits et des points
plt.plot(x, np.sin(x - 2), color='0.75', linestyle='dashdot', label='gris')
# Couleur spécifié en RGB, avec des points
plt.plot(x, np.sin(x - 3), color='#FF0000', linestyle='dotted', label='rouge')

# Les limites des axes, essayez aussi les arguments 'tight' et 'equal' pour voir leur effet
plt.axis([-1, 11, -3, 1.5]);

# Les labels
plt.title("Un exemple de graphe")

# La légende est générée à partir de l'argument label de la fonction plot. 
# L'argument loc spécifie le placement de la légende
plt.legend(loc='lower left')

# Titres des axes
ax = ax.set(xlabel='x', ylabel='sin(x)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 9
#       5 ax = plt.axes()
#       7 # Modifier l'affichage de la courbe :
#       8 # Couleur spécifiée par son nom, type de ligne, valeur étiquette
# ----> 9 plt.plot(x, np.sin(x - 0), color='blue', linestyle='solid', label='bleu')
#      10 # Nom court pour la couleur, ligne avec des traits
#      11 plt.plot(x, np.sin(x - 1), color='g', linestyle='dashed', label='vert', linewidth=10)
#
# NameError: name 'x' is not defined

# %% [markdown]
# <span style="color:blue">QUESTION : Modifier le code précédent pour afficher la racine carré (sqrt) de x sur une courbe pointillée rose. </span>
#     <span style="color:red">XXXXXXXX
# </span>

# %% [markdown]
# ## 2. Visualiser des données discrètes
#
# Dans la vie réelle, les données que nous analysons sont souvent bruitées, c'est-à-dire qu'il existe une part d'incertitude sur leur valeur réelle.
#
# Il est extrêmement important d'en tenir compte non seulement lors de l'analyse des données,  mais aussi quand on veut les présenter.

# %% [markdown]
# Dans le cas de données discrètes (des points), nous utilisons souvent les barres d'erreur pour représenter,  pour chaque point, l'incertitude quant à la valeur exacte.
# Souvent la longueur des barres correspond à l'écart type des observations empiriques.
# C'est chose aisée avec Matplotlib.

# %%
x = np.linspace(0, 10, 50)
dy = 0.8
y = np.sin(x) + dy * np.random.randn(50)
plt.errorbar(x, y, yerr=dy, fmt='.k')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 x = np.linspace(0, 10, 50)
#       2 dy = 0.8
#       3 y = np.sin(x) + dy * np.random.randn(50)
#
# NameError: name 'np' is not defined

# %% [markdown]
# <span style="color:blue">QUESTION : que signifient les arguments de la fonction _Errorbar_ ? </span>
#     <span style="color:red">XXXXXXXX
# </span>

# %% [markdown]
# Errorbar  permet aussi de personnaliser encore plus l'apparence du graphe.
# Je vous invite fortement à consulter sa documentation.

# %%
plt.errorbar(x, y, yerr=dy, fmt='.k', color='black', ecolor='lightgray', elinewidth=3, capsize=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 plt.errorbar(x, y, yerr=dy, fmt='.k', color='black', ecolor='lightgray', elinewidth=3, capsize=0)
#
# NameError: name 'x' is not defined

# %% [markdown]
# ## 3 Visualiser des données continues
#
# Nous avons parfois besoin de représenter une incertitude sur une fonction continue.
# On peut faire cela avec la fonction  plot  combinée avec la fonction  fill_between.

# %%
print(plt.style.available[:6])

# Notez la taille de la figure
fig = plt.figure(figsize=(12,8))
for i in range(6):
    # On peut ajouter des sous graphes ainsi
    fig.add_subplot(3,2,i+1)
    plt.style.use(plt.style.available[i])
    plt.plot(x, y)
    
    # Pour ajouter du texte
    plt.text(s=plt.style.available[i], x=5, y=2, color='red')
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 9
#       7 fig.add_subplot(3,2,i+1)
#       8 plt.style.use(plt.style.available[i])
# ----> 9 plt.plot(x, y)
#      11 # Pour ajouter du texte
#      12 plt.text(s=plt.style.available[i], x=5, y=2, color='red')
#
# NameError: name 'x' is not defined

# %% [markdown]
# <span style="color:blue">QUESTION : A quoi sert ce code ? Compléter le texte ci-dessous :</span>
# * <span style="color:blue">Ce code permet de
# * <span style="color:blue">Le premier argument de la fonction add_subplot est
# * <span style="color:blue">Le deuxième est
# * <span style="color:blue">Le troisième est
# * <span style="color:blue">Pour des raisons historiques, les sous-graphes
# * <span style="color:blue">Le graphe tout en haut à gauche est donc</span>

# %% [markdown]
# ## 4. Afficher un diagramme en barre

# %%
import matplotlib.pyplot as plt

# Données à afficher
x = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]

x_pos = [i for i, _ in enumerate(x)]
plt.bar(x_pos, popularity, color='blue')
plt.xlabel("Languages")
plt.ylabel("Popularity")
plt.title("PopularitY of Programming Language\n" + "Worldwide, Oct 2017 compared to a year ago")
plt.xticks(x_pos, x)
# Turn on the grid
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
# Customize the minor grid
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %% [markdown]
# ## 5. Afficher un camembert

# %%
import matplotlib.pyplot as plt
# Data to plot
languages = 'Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++'
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd", "#8c564b"]
# explode 1st slice
explode = (0, 0.2, 0, 0,0,0)  
# Plot
plt.pie(popularity, explode=explode, labels=languages, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()

# %% [markdown]
# ## 6. Afficher un diagramme à moustaches

# %%
# Import libraries
import matplotlib.pyplot as plt
import numpy as np

# Creating dataset
np.random.seed(10)

data_1 = np.random.normal(100, 10, 200)
data_2 = np.random.normal(90, 20, 200)
data_3 = np.random.normal(80, 30, 200)
data_4 = np.random.normal(70, 40, 200)
data = [data_1, data_2, data_3, data_4]

fig = plt.figure(figsize =(10, 7))

# Creating axes instance
ax = fig.add_axes([0, 0, 1, 1])

# Creating plot
bp = ax.boxplot(data)

# show plot
plt.show()
